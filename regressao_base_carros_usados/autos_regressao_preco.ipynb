# %% [markdown]
# # Prevendo o preço de Automóveis

# %%
import pandas as pd
base = pd.read_csv("./autos.csv", encoding="ISO-8859-1")
base.head()
# Out:
#            dateCrawled                            name  seller offerType  \
# 0  2016-03-24 11:52:17                      Golf_3_1.6  privat   Angebot
# 1  2016-03-24 10:58:45            A5_Sportback_2.7_Tdi  privat   Angebot
# 2  2016-03-14 12:52:21  Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 3  2016-03-17 16:54:04              GOLF_4_1_4__3TÜRER  privat   Angebot
# 4  2016-03-31 17:25:20  Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
#
#    price abtest vehicleType  yearOfRegistration    gearbox  powerPS  model  \
# 0    480   test         NaN                1993    manuell        0   golf
# 1  18300   test       coupe                2011    manuell      190    NaN
# 2   9800   test         suv                2004  automatik      163  grand
# 3   1500   test  kleinwagen                2001    manuell       75   golf
# 4   3600   test  kleinwagen                2008    manuell       69  fabia
#
#    kilometer  monthOfRegistration fuelType       brand notRepairedDamage  \
# 0     150000                    0   benzin  volkswagen               NaN
# 1     125000                    5   diesel        audi                ja
# 2     125000                    8   diesel        jeep               NaN
# 3     150000                    6   benzin  volkswagen              nein
# 4      90000                    7   diesel       skoda              nein
#
#            dateCreated  nrOfPictures  postalCode             lastSeen
# 0  2016-03-24 00:00:00             0       70435  2016-04-07 03:16:57
# 1  2016-03-24 00:00:00             0       66954  2016-04-07 01:46:50
# 2  2016-03-14 00:00:00             0       90480  2016-04-05 12:47:46
# 3  2016-03-17 00:00:00             0       91074  2016-03-17 17:40:17
# 4  2016-03-31 00:00:00             0       60437  2016-04-06 10:17:21

# %% [markdown]
# # Removendo colunas que não agregam na base de dados

# %% [markdown]
#  Isso é feito afim de reduzir a base de dados para os atributos mais relevantes, assim, a o algorítimo terá apenas dados relevantes sobre o problema em questão

# %%
base = base.drop("dateCrawled", axis=1)
base = base.drop("nrOfPictures", axis=1)
base = base.drop("dateCreated", axis=1)
base = base.drop("postalCode", axis=1)
base = base.drop("lastSeen", axis=1)

base.shape
# Out:
# (371528, 15)

# %%
base["name"].value_counts()
# Out:
# Ford_Fiesta                                                          657
# BMW_318i                                                             627
# Opel_Corsa                                                           622
# Volkswagen_Golf_1.4                                                  603
# BMW_316i                                                             523
#                                                                     ...
# Unikatischer_Opel_Astra                                                1
# Golf_VII_Comfortline_BMT_1_6l_TDI_/_Garantie_/_nur_34000_km_/_Top      1
# Volkswagen_Touran_1.9_TDI_Conceptline__AHK                             1
# Audi_tt_8n_Grill                                                       1
# Golf_4____Top_Zustand                                                  1
# Name: name, Length: 233531, dtype: int64

# %%
base = base.drop("name", axis=1)

# %%
base["seller"].value_counts()
# Out:
# privat        371525
# gewerblich         3
# Name: seller, dtype: int64

# %%
base = base.drop("seller", axis=1)

# %%
base["offerType"].value_counts()
# Out:
# Angebot    371516
# Gesuch         12
# Name: offerType, dtype: int64

# %%
base = base.drop("offerType", axis=1)

# %%
base.shape
# Out:
# (371528, 12)

# %% [markdown]
# # Pré-Processamento de valores inconsistente

# %%
i1 = base.loc[base.price <= 10]

# %%
i1.head()
# Out:
#      price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 7        0     test   limousine                1980  manuell       50
# 40       0     test         NaN                1990      NaN        0
# 60       1  control         suv                1994  manuell      286
# 91       1  control   limousine                1995  manuell      113
# 115      0     test         NaN                2017  manuell        0
#
#         model  kilometer  monthOfRegistration fuelType           brand  \
# 7      andere      40000                    7   benzin      volkswagen
# 40      corsa     150000                    1   benzin            opel
# 60        NaN     150000                   11      NaN  sonstige_autos
# 91   e_klasse     150000                    4   diesel   mercedes_benz
# 115      golf       5000                   12   benzin      volkswagen
#
#     notRepairedDamage
# 7                nein
# 40                NaN
# 60                NaN
# 91               nein
# 115               NaN

# %%
base = base[base.price > 10]

# %%
base.shape
# Out:
# (359410, 12)

# %%
i2 = base.loc[base.price > 350000]

# %%
i2.head()
# Out:
#           price   abtest vehicleType  yearOfRegistration  gearbox  powerPS  \
# 1846     579000  control       coupe                1980  manuell      277
# 10649    420000  control       coupe                2004  manuell      483
# 14663  11111111  control       coupe                2003  manuell       64
# 16889   1000000  control       kombi                1998      NaN        0
# 20143   1250000     test       coupe                2016  manuell      500
#
#         model  kilometer  monthOfRegistration fuelType       brand  \
# 1846   andere      20000                   12   benzin         bmw
# 10649     911      50000                    4   benzin     porsche
# 14663    polo     150000                    2   benzin  volkswagen
# 16889  mondeo     150000                    0   benzin        ford
# 20143     911       5000                    3   benzin     porsche
#
#       notRepairedDamage
# 1846               nein
# 10649              nein
# 14663               NaN
# 16889                ja
# 20143              nein

# %%
base = base.loc[base.price < 350000]

# %%
base.shape
# Out:
# (359291, 12)

# %% [markdown]
# # Pré-processamento de valores faltantes

# %%
# Verificando os valores faltantes do atributo vehicleType para que posteriormente no código seja modificados

base[pd.isnull(base["vehicleType"])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 16        300     test         NaN                2016        NaN       60
# 22       2900     test         NaN                2018    manuell       90
# 26       5555  control         NaN                2017    manuell      125
# 31        899  control         NaN                2016    manuell       60
# ...       ...      ...         ...                 ...        ...      ...
# 371495    180  control         NaN                1995        NaN        0
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 0           golf     150000                    0   benzin      volkswagen
# 16          polo     150000                    0   benzin      volkswagen
# 22        meriva     150000                    5   benzin            opel
# 26            c4     125000                    4      NaN         citroen
# 31          clio     150000                    6   benzin         renault
# ...          ...        ...                  ...      ...             ...
# 371495       NaN     125000                    3   benzin            opel
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 0                    NaN
# 16                   NaN
# 22                  nein
# 26                  nein
# 31                   NaN
# ...                  ...
# 371495               NaN
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN
#
# [33546 rows x 12 columns]

# %%
# Verificando qual o vehicleType mais se repete na base de dados, afim de subistituir os valores faltantes desse
# atibuto

base["vehicleType"].value_counts() # limousine
# Out:
# limousine     93614
# kleinwagen    78014
# kombi         65921
# bus           29699
# cabrio        22509
# coupe         18386
# suv           14477
# andere         3125
# Name: vehicleType, dtype: int64

# %%
# Verificando os valores faltantes desse atribulto para que eles sejam subistituidos

base.loc[pd.isnull(base["gearbox"])]
# Out:
#         price   abtest vehicleType  yearOfRegistration gearbox  powerPS  \
# 15        450     test  kleinwagen                1910     NaN        0
# 16        300     test         NaN                2016     NaN       60
# 32        245     test   limousine                1994     NaN        0
# 37       1500     test         NaN                2016     NaN        0
# 70       1200     test       coupe                2001     NaN        0
# ...       ...      ...         ...                 ...     ...      ...
# 371443   3300  control       kombi                2006     NaN        0
# 371460   3500  control         NaN                1995     NaN        0
# 371486    350  control  kleinwagen                1996     NaN       65
# 371495    180  control         NaN                1995     NaN        0
# 371523   2200     test         NaN                2005     NaN        0
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 15          ka       5000                    0   benzin            ford
# 16        polo     150000                    0   benzin      volkswagen
# 32        golf     150000                    2   benzin      volkswagen
# 37      kangoo     150000                    1   diesel         renault
# 70       astra     150000                    0      NaN            opel
# ...        ...        ...                  ...      ...             ...
# 371443  touran     150000                    7   diesel      volkswagen
# 371460    polo     150000                    0      NaN      volkswagen
# 371486   punto     150000                    0      NaN            fiat
# 371495     NaN     125000                    3   benzin            opel
# 371523     NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 15                   NaN
# 16                   NaN
# 32                  nein
# 37                  nein
# 70                   NaN
# ...                  ...
# 371443               NaN
# 371460               NaN
# 371486               NaN
# 371495               NaN
# 371523               NaN
#
# [17236 rows x 12 columns]

# %%
# verificando qual o gearbox mais aparece na base de dados, para que posteriormente possa ser utilizada NaN
# desse atribulto

base["gearbox"].value_counts() # manuell
# Out:
# manuell      266547
# automatik     75508
# Name: gearbox, dtype: int64

# %%
# Verificando os valores faltantes desse atribulto para que eles sejam subistituidos

base.loc[pd.isnull(base["model"])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 1       18300     test       coupe                2011    manuell      190
# 83        350  control  kleinwagen                1997    manuell       54
# 139      1450  control   limousine                1992    manuell      136
# 156      6799  control  kleinwagen                2009        NaN       60
# 165       500  control  kleinwagen                1999    manuell        0
# ...       ...      ...         ...                 ...        ...      ...
# 371399    560  control  kleinwagen                2001  automatik      170
# 371476   9400  control       kombi                2007    manuell      200
# 371495    180  control         NaN                1995        NaN        0
# 371509   1900     test         NaN                2000    manuell      110
# 371523   2200     test         NaN                2005        NaN        0
#
#        model  kilometer  monthOfRegistration fuelType           brand  \
# 1        NaN     125000                    5   diesel            audi
# 83       NaN     150000                    3      NaN            fiat
# 139      NaN     150000                    0      NaN            audi
# 156      NaN      20000                    5   benzin      volkswagen
# 165      NaN     150000                    0   benzin         renault
# ...      ...        ...                  ...      ...             ...
# 371399   NaN      90000                    0   benzin            fiat
# 371476   NaN     150000                    4   diesel  sonstige_autos
# 371495   NaN     125000                    3   benzin            opel
# 371509   NaN     150000                    7      NaN      volkswagen
# 371523   NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 1                     ja
# 83                    ja
# 139                 nein
# 156                 nein
# 165                 nein
# ...                  ...
# 371399                ja
# 371476                ja
# 371495               NaN
# 371509              nein
# 371523               NaN
#
# [17967 rows x 12 columns]

# %%
# verificando qual o model mais aparece na base de dados, para que posteriormente possa ser utilizada NaN
# desse atribulto

base["model"].value_counts() # golf
# Out:
# golf               28989
# andere             25560
# 3er                19905
# polo               12604
# corsa              12149
#                    ...
# serie_2                8
# rangerover             6
# serie_3                3
# discovery_sport        1
# serie_1                1
# Name: model, Length: 251, dtype: int64

# %%
# Verificando os valores faltantes desse atribulto para que eles sejam subistituidos

base.loc[pd.isnull(base["fuelType"])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 9         999     test  kleinwagen                1998    manuell      101
# 13       2500  control       kombi                2004    manuell      131
# 26       5555  control         NaN                2017    manuell      125
# 36       1600  control      andere                1991    manuell       75
# 41       7500  control   limousine                2002  automatik      306
# ...       ...      ...         ...                 ...        ...      ...
# 371496   3850     test      cabrio                2006    manuell      108
# 371504   2600  control         NaN                2005  automatik        0
# 371509   1900     test         NaN                2000    manuell      110
# 371519   5250  control         NaN                2016  automatik      150
# 371523   2200     test         NaN                2005        NaN        0
#
#            model  kilometer  monthOfRegistration fuelType           brand  \
# 9           golf     150000                    0      NaN      volkswagen
# 13        passat     150000                    2      NaN      volkswagen
# 26            c4     125000                    4      NaN         citroen
# 36        kadett      70000                    0      NaN            opel
# 41      e_klasse     150000                    4      NaN   mercedes_benz
# ...          ...        ...                  ...      ...             ...
# 371496   2_reihe     125000                    2      NaN         peugeot
# 371504  c_klasse     150000                    9      NaN   mercedes_benz
# 371509       NaN     150000                    7      NaN      volkswagen
# 371519       159     150000                   12      NaN      alfa_romeo
# 371523       NaN      20000                    1      NaN  sonstige_autos
#
#        notRepairedDamage
# 9                    NaN
# 13                  nein
# 26                  nein
# 36                   NaN
# 41                   NaN
# ...                  ...
# 371496              nein
# 371504               NaN
# 371509              nein
# 371519              nein
# 371523               NaN
#
# [29391 rows x 12 columns]

# %%
# verificando qual o fuelType mais aparece na base de dados, para que posteriormente possa ser utilizada NaN
# desse atribulto

base["fuelType"].value_counts() # benzin
# Out:
# benzin     217582
# diesel     106002
# lpg          5222
# cng           557
# hybrid        271
# andere        165
# elektro       101
# Name: fuelType, dtype: int64

# %%
# Verificando os valores faltantes desse atribulto para que eles sejam subistituidos

base.loc[pd.isnull(base["notRepairedDamage"])]
# Out:
#         price   abtest vehicleType  yearOfRegistration    gearbox  powerPS  \
# 0         480     test         NaN                1993    manuell        0
# 2        9800     test         suv                2004  automatik      163
# 8       14500  control         bus                2014    manuell      125
# 9         999     test  kleinwagen                1998    manuell      101
# 12        999  control       kombi                1995    manuell      115
# ...       ...      ...         ...                 ...        ...      ...
# 371507   5999     test       kombi                2005    manuell      140
# 371514    999  control      cabrio                2000    manuell       95
# 371515   1690     test       kombi                2004    manuell       55
# 371523   2200     test         NaN                2005        NaN        0
# 371526   3400     test       kombi                2002    manuell      100
#
#          model  kilometer  monthOfRegistration fuelType           brand  \
# 0         golf     150000                    0   benzin      volkswagen
# 2        grand     125000                    8   diesel            jeep
# 8        c_max      30000                    8   benzin            ford
# 9         golf     150000                    0      NaN      volkswagen
# 12      passat     150000                   11   benzin      volkswagen
# ...        ...        ...                  ...      ...             ...
# 371507      a4     150000                    4   diesel            audi
# 371514  megane     150000                    4   benzin         renault
# 371515   fabia     150000                    4   benzin           skoda
# 371523     NaN      20000                    1      NaN  sonstige_autos
# 371526    golf     150000                    6   diesel      volkswagen
#
#        notRepairedDamage
# 0                    NaN
# 2                    NaN
# 8                    NaN
# 9                    NaN
# 12                   NaN
# ...                  ...
# 371507               NaN
# 371514               NaN
# 371515               NaN
# 371523               NaN
# 371526               NaN
#
# [65986 rows x 12 columns]

# %%
# verificando qual o notRepairedDamage mais aparece na base de dados, para que posteriormente possa ser utilizada NaN
# desse atribulto

base["notRepairedDamage"].value_counts() # nein
# Out:
# nein    259301
# ja       34004
# Name: notRepairedDamage, dtype: int64

# %% [markdown]
# # Substituindo os valores faltantes da base de dados

# %%
valores = {"vehicleType": "limousine", "gearbox": "manuell",
           "model": "golf", "fuelType": "benzin", "notRepairedDamage": "nein"}
print(valores)
# Out:
# {'vehicleType': 'limousine', 'gearbox': 'manuell', 'model': 'golf', 'fuelType': 'benzin', 'notRepairedDamage': 'nein'}

# %% [markdown]
#    ### Subistituindo os valores NaN das colunas citadas no Dicionário assina, pelas chaves do dict

# %%
base = base.fillna(value=valores)

# %% [markdown]
# # Separando os atributos Previsores e da Classe

# %%
# Separando os previsores em um array numpy

previsores = base.iloc[:, 1:13].values

# %%
# Separando a classe em um array numpy

preco_real = base.iloc[:, 0].values

# %% [markdown]
# # Aplicando o LabelEncoder e o One Hot Encoder
# É uma Classe do pandas que transforma dados categóricos(palavras) em dados numéricos, isso é feito, pois, modelos de Machile Learning só conseguem utilizar valores numéricos para realizar os cálculos

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

labelencoder_previsores = LabelEncoder()
onehotencorder = ColumnTransformer(transformers=[("OneHot", 
                                                  OneHotEncoder(), 
                                                  [0,1,3,5,8,9,10])],
                                                   remainder='passthrough')
previsores = onehotencorder.fit_transform(previsores).toarray()

# %%
previsores.shape
# Out:
# (359291, 316)

# %% [markdown]
# # Criar a Estrutura do modelo de Regressão

# %%
# Importando as libs

from keras.models import Sequential
from keras.layers import Dense

# Criando o modelo
regressor = Sequential()
regressor.add(Dense(units=158, activation="relu", input_dim=316))
regressor.add(Dense(units=158, activation="relu"))
regressor.add(Dense(units=1, activation="linear"))

# Compilando o modelo criado
regressor.compile(loss="mean_absolute_error", optimizer="adam", metrics=["mean_absolute_error"])

# %%
# Treinando o modelo
regressor.fit(previsores, preco_real, batch_size=300, epochs=50)
# Out:
# Epoch 1/50
# 1198/1198 [==============================] - 21s 13ms/step - loss: 4318.1617 - mean_absolute_error: 4318.1617
# Epoch 2/50
# 1198/1198 [==============================] - 17s 15ms/step - loss: 3405.5071 - mean_absolute_error: 3405.5071
# Epoch 3/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 3110.4522 - mean_absolute_error: 3110.4522
# Epoch 4/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2951.9417 - mean_absolute_error: 2951.9417
# Epoch 5/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2840.3579 - mean_absolute_error: 2840.3579
# Epoch 6/50
# 1198/1198 [==============================] - 10s 8ms/step - loss: 2773.9577 - mean_absolute_error: 2773.9576
# Epoch 7/50
# 1198/1198 [==============================] - 9s 8ms/step - loss: 2719.2023 - mean_absolute_error: 2719.2023
# Epoch 8/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2657.2239 - mean_absolute_error: 2657.2239
# Epoch 9/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2647.0431 - mean_absolute_error: 2647.0433
# Epoch 10/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2601.0081 - mean_absolute_error: 2601.0081
# Epoch 11/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2545.2674 - mean_absolute_error: 2545.2674
# Epoch 12/50
# 1198/1198 [==============================] - 9s 8ms/step - loss: 2549.3881 - mean_absolute_error: 2549.3880
# Epoch 13/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2480.3217 - mean_absolute_error: 2480.3217
# Epoch 14/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2492.6245 - mean_absolute_error: 2492.6245
# Epoch 15/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2502.1586 - mean_absolute_error: 2502.1586
# Epoch 16/50
# 1198/1198 [==============================] - 18s 15ms/step - loss: 2482.6367 - mean_absolute_error: 2482.6367
# Epoch 17/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2445.2139 - mean_absolute_error: 2445.2139
# Epoch 18/50
# 1198/1198 [==============================] - 16s 14ms/step - loss: 2434.4087 - mean_absolute_error: 2434.4087
# Epoch 19/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2416.7928 - mean_absolute_error: 2416.7928
# Epoch 20/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2403.2937 - mean_absolute_error: 2403.2937
# Epoch 21/50
# 1198/1198 [==============================] - 19s 16ms/step - loss: 2423.7187 - mean_absolute_error: 2423.7188
# Epoch 22/50
# 1198/1198 [==============================] - 17s 14ms/step - loss: 2417.4716 - mean_absolute_error: 2417.4716
# Epoch 23/50
# 1198/1198 [==============================] - 18s 15ms/step - loss: 2395.1503 - mean_absolute_error: 2395.1503 2s - l
# Epoch 24/50
# 1198/1198 [==============================] - 15s 12ms/step - loss: 2403.3253 - mean_absolute_error: 2403.3253
# Epoch 25/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2378.6813 - mean_absolute_error: 2378.6811
# Epoch 26/50
# 1198/1198 [==============================] - 10s 8ms/step - loss: 2374.9487 - mean_absolute_error: 2374.9487
# Epoch 27/50
# 1198/1198 [==============================] - 10s 8ms/step - loss: 2368.5602 - mean_absolute_error: 2368.5602
# Epoch 28/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2387.7187 - mean_absolute_error: 2387.7187
# Epoch 29/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2370.5210 - mean_absolute_error: 2370.5210
# Epoch 30/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2349.3144 - mean_absolute_error: 2349.3143
# Epoch 31/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2355.1090 - mean_absolute_error: 2355.1090
# Epoch 32/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2348.6048 - mean_absolute_error: 2348.6048
# Epoch 33/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2356.2857 - mean_absolute_error: 2356.2857
# Epoch 34/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2328.8382 - mean_absolute_error: 2328.8382
# Epoch 35/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2350.1204 - mean_absolute_error: 2350.1204
# Epoch 36/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2339.3915 - mean_absolute_error: 2339.3915
# Epoch 37/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2350.8881 - mean_absolute_error: 2350.8881
# Epoch 38/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2371.6933 - mean_absolute_error: 2371.6933
# Epoch 39/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2340.5247 - mean_absolute_error: 2340.5247
# Epoch 40/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2351.8449 - mean_absolute_error: 2351.8449
# Epoch 41/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2323.3544 - mean_absolute_error: 2323.3544
# Epoch 42/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2317.7236 - mean_absolute_error: 2317.7236
# Epoch 43/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2324.3474 - mean_absolute_error: 2324.3474
# Epoch 44/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2353.8232 - mean_absolute_error: 2353.8232
# Epoch 45/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2325.6927 - mean_absolute_error: 2325.6927
# Epoch 46/50
# 1198/1198 [==============================] - 9s 8ms/step - loss: 2324.0860 - mean_absolute_error: 2324.0859
# Epoch 47/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2299.3503 - mean_absolute_error: 2299.3503
# Epoch 48/50
# 1198/1198 [==============================] - 9s 7ms/step - loss: 2328.5741 - mean_absolute_error: 2328.5741
# Epoch 49/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2350.3717 - mean_absolute_error: 2350.3717
# Epoch 50/50
# 1198/1198 [==============================] - 8s 7ms/step - loss: 2297.6686 - mean_absolute_error: 2297.6686
